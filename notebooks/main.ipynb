# %%
from collections import namedtuple
from pathlib import Path

import pandas as pd

# %%
CSVFile = namedtuple('CSVFile', field_names=['path', 'form_type', 'content'])
DATA_HOME = Path('../data')
DATA_OUTPUT = DATA_HOME / 'output'
COLUMNS = ['currency', 'location', 'isUS', 'filingYear', 'market_cap_category', 'exchange', 'isDelisted', 'category', 'sicSector', 'sicIndustry',]
MAX_SAMPLE_SIZE_PER_COLUMN_TYPE = 50

csv_files = [
    CSVFile(DATA_HOME / 'metadata_10-Q_2023to2003_cleaned_onlyhtm_with_company_details.csv.gz', '10-Q', None),
    CSVFile(DATA_HOME / 'metadata_10-K_2023to2003_cleaned_onlyhtm_with_company_details.csv.gz', '10-K', None),
    CSVFile(DATA_HOME / 'metadata_8-K_2023to2003_cleaned_onlyhtm_with_company_details.csv.gz', '8-K', None),
]

# %%
def download_html_file_callback(namespace: str):
    def wrapper(row):
        pass
    return wrapper

# %%
for csv_file in csv_files:
    df = pd.read_csv(csv_file.path, compression='gzip', low_memory=False)
    df.apply(download_html_file_callback(''), axis=1)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# ...
